# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target URLs and multiple API requests.

# Dependencies
import requests
import json

# Retrieve Google API key from config.py
from config import gkey

# %%
# 1. What are the geocoordinates (latitude/longitude) of Seattle, Washington?
target = "Seattle, Washington"
params = {
    "address": target,
    "key": gkey
}
base_url = "https://maps.googleapis.com/maps/api/geocode/json?"
seattle_wa = requests.get(base_url, params).json()
seattle_wa
# Out:
# {'results': [{'address_components': [{'long_name': 'Seattle',
#      'short_name': 'Seattle',
#      'types': ['locality', 'political']},
#     {'long_name': 'King County',
#      'short_name': 'King County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Washington',
#      'short_name': 'WA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Seattle, WA, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 47.734145,
#       'lng': -122.2244331},
#      'southwest': {'lat': 47.4919119, 'lng': -122.4596959}},
#     'location': {'lat': 47.6062095, 'lng': -122.3320708},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 47.734145, 'lng': -122.2244331},
#      'southwest': {'lat': 47.4919119, 'lng': -122.4596959}}},
#    'place_id': 'ChIJVTPokywQkFQRmtVEaUZlJRA',
# ...

# %%
print(seattle_wa["results"][0]["geometry"]["location"]["lat"])
print(seattle_wa["results"][0]["geometry"]["location"]["lng"])
# Out:
# 47.6062095
# -122.3320708

# %%
# 2. What are the geocoordinates (latitude/longitude) of The White House?
target = "White House, Washington, D.C."
params = {
    "address": target,
    "key": gkey
}
base_url = "https://maps.googleapis.com/maps/api/geocode/json?"
white_house = requests.get(base_url, params).json()

print(white_house["results"][0]["geometry"]["location"]["lat"])
print(white_house["results"][0]["geometry"]["location"]["lng"])
# Out:
# 38.8976763
# -77.0365298

# %%
# 3. Find the name and address of a bike store in Seattle, Washington.
#    Hint: See https://developers.google.com/places/web-service/supported_types

target_type = "bicycle_store"
seattle_coords = "47.6129432, -122.4821482"
radius = 8000

params = {
    "location": seattle_coords,
    "types": target_type,
    "radius": radius,
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

seattle_bikes = requests.get(base_url, params).json()

# %%
print(seattle_bikes["results"][0]["name"])
print(seattle_bikes["results"][0]["vicinity"])
# Out:
# Classic Cycle
# 740 Winslow Way East, Bainbridge Island

# %%
# 4. Find a balloon store near the White House.

target_search = "balloon store"
wh_coords = "38.8976805, -77.0387185"
radius = 8000

params = {
    "location": wh_coords,
    "keyword": target_search,
    "radius": radius,
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

wh_balloons = requests.get(base_url, params).json()
wh_balloons
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.8484985, 'lng': -77.1233929},
#     'viewport': {'northeast': {'lat': 38.84973412989272,
#       'lng': -77.12213512010727},
#      'southwest': {'lat': 38.84703447010727, 'lng': -77.12483477989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Party City',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2322,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117913403659594343780">LUIS FIGUEROA</a>'],
#      'photo_reference': 'Aap_uEA20aDHRAs8BmD0EyTrrLdC1mEQFuuhe0zgiejZ2QcLKXaz474lmfsjZLXRqcHO0MH7RbALdeUfxPFK10cgn8e8HE-CxU4rQ-39jzKGRnEpXixHwZc7iv8ZVB_XaVfbNZwmyvKYZY3_D4_ifWB9PnJb5VSAfdvmb89q8316sOK3K5Tc',
#      'width': 4128}],
#    'place_id': 'ChIJxaFOC_Ozt4kRthO-u4Mst8U',
#    'plus_code': {'compound_code': 'RVXG+9J Falls Church, Virginia',
# ...

# %%
print(wh_balloons["results"][0]["name"])
print(wh_balloons["results"][0]["vicinity"])
# Out:
# Party City
# 5522 Leesburg Pike, Falls Church

# %%
# 5. Find the nearest dentist to your house.
#    Hint: Use Google Maps to find your latitude and Google Places to find the
#    dentist. You will also need the rankby property.
target_type = "dentist"
home_coords = "33.4610141,-82.2536615"
radius = 8000

params = {
    "location": home_coords,
    "type": target_type,
    "rankby": "distance",
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

home_dentist = requests.get(base_url, params).json()
home_dentist
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 33.5016746, 'lng': -82.23920439999999},
#     'viewport': {'northeast': {'lat': 33.5029371802915,
#       'lng': -82.2380744697085},
#      'southwest': {'lat': 33.5002392197085, 'lng': -82.2407724302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Patriots Park Dental',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3226,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112532033124984753079">Patriots Park Dental</a>'],
#      'photo_reference': 'Aap_uED8GAzPHBTNUHkd43gv3oO4MQ10hoD7sajeMFRvGZ2bxEL-JqaibYvTV6kJKfTc6qLyAnxAxsp0cFHwq0AyTwe4qTx3-W2gL-dm6h5swRwxPTSZdSlPKHIEekSLfQrmic6_7xpNBQnt2DVv9I_GoHW7F94AZorx4hBVmuIAdLZKt23u',
#      'width': 4871}],
#    'place_id': 'ChIJDYo2bdR_94gRQSNbxOlFfnU',
# ...

# %%
print(home_dentist["results"][0]["name"])
print(home_dentist["results"][0]["vicinity"])
# Out:
# Patriots Park Dental
# 2054 Warrior Way, Grovetown

# %%
# 6. Bonus: Find the names and addresses of the top five restaurants in your home city.
#    Hint: Read about "Text Search Results"
# (https://developers.google.com/places/web-service/search#TextSearchRequests)
target_query = "top rated restaurants Concord, NC"

params = {
    "query": target_query,
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/place/textsearch/json"

restaurants = requests.get(base_url, params).json()
restaurants["results"]
# Out:
# [{'business_status': 'OPERATIONAL',
#   'formatted_address': '1480 Concord Pkwy N # 70, Concord, NC 28025, United States',
#   'geometry': {'location': {'lat': 35.4401101, 'lng': -80.60311109999999},
#    'viewport': {'northeast': {'lat': 35.44136512989272,
#      'lng': -80.60163677010728},
#     'southwest': {'lat': 35.43866547010727, 'lng': -80.60433642989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Yum Yum!',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109086038527083016990">ceaser Yazan</a>'],
#     'photo_reference': 'Aap_uEBCJ20lYloHf5svGY5m22dOTHVlsxS13i472ZfRjGobqUEEOXqveSQ_xZdJjpyoOtQ9xoPKn5jL39M4XNcyr-btaHzp4FWTxsQn7zSEWgt4W3JhEicZyz27g8DCuaNbi3QS0N2yFZH-CbR74g60qOG5pqd8iW-UuaqD4AWe8kr2wOAQ',
#     'width': 3024}],
#   'place_id': 'ChIJq8p0ZVsPVIgR87FpjUGs2qI',
# ...

# %%
for x in range(0,5):
    print(restaurants["results"][x]["name"], restaurants["results"][x]["formatted_address"])
# Out:
# Yum Yum! 1480 Concord Pkwy N # 70, Concord, NC 28025, United States
# Gianni's Trattoria 16 Union St S, Concord, NC 28025, United States
# Razzoo's Cajun Cafe 8011 Concord Mills Boulevard, Concord, NC 28027, United States
# 2 Gals Kitchen 80 Union St S, Concord, NC 28025, United States
# Bonefish Grill 8503 Concord Mills Boulevard, Concord, NC 28027, United States
