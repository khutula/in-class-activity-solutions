# %%
import gmaps
import pandas as pd
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# Create aiport dataframe
csvfile = pd.read_csv("../Resources/Airport_Output.csv")

airport_df = pd.DataFrame(csvfile)
del airport_df["Unnamed: 0"]
airport_df.dropna(inplace=True)
airport_df.head()
# Out:
#             City         State        Lat         Lng  \
# 0  New York City      New York  40.712775  -74.005973
# 1    Los Angeles    California  34.052234 -118.243685
# 2        Chicago      Illinois  41.878114  -87.629798
# 3        Houston         Texas  29.760427  -95.369803
# 4   Philadelphia  Pennsylvania  39.952584  -75.165222
#
#                            Airport Name                   Airport Address  \
# 0  Newark Liberty International Airport             3 Brewster Rd, Newark
# 1     Los Angeles International Airport          1 World Way, Los Angeles
# 2          O'Hare International Airport       10000 W O'Hare Ave, Chicago
# 3              William P. Hobby Airport        7800 Airport Blvd, Houston
# 4    Philadelphia International Airport  8000 Essington Ave, Philadelphia
#
#    Airport Rating
# 0             3.2
# 1             3.5
# 2             3.6
# 3             4.0
# 4             3.3

# %%
# Store latitude and longitude in locations
locations = airport_df[["Lat","Lng"]]

# Filla NaN values and convert to float
rating = airport_df["Airport Rating"].astype(float)
airport_df
# Out:
#                City         State        Lat         Lng  \
# 0     New York City      New York  40.712775  -74.005973
# 1       Los Angeles    California  34.052234 -118.243685
# 2           Chicago      Illinois  41.878114  -87.629798
# 3           Houston         Texas  29.760427  -95.369803
# 4      Philadelphia  Pennsylvania  39.952584  -75.165222
# ..              ...           ...        ...         ...
# 94  North Las Vegas        Nevada  36.198859 -115.117501
# 95          Fremont    California  37.548270 -121.988572
# 96      Baton Rouge     Louisiana  30.451468  -91.187147
# 97         Richmond      Virginia  37.540725  -77.436048
# 99   San Bernardino    California  34.108345 -117.289765
#
#                             Airport Name  \
# 0   Newark Liberty International Airport
# 1      Los Angeles International Airport
# 2           O'Hare International Airport
# 3               William P. Hobby Airport
# 4     Philadelphia International Airport
# ...

# %%
# Plot Heatmap

figure_layout = {
    'width': '400px',
    'height': '400px',
    'border': '1px solid black',
    'padding': '1px'
}
fig = gmaps.figure(layout=figure_layout)

fig = gmaps.figure(map_type='HYBRID')
heatmap_layer = gmaps.heatmap_layer(locations, weights=rating, dissipating=False,
    max_intensity=5, point_radius=1)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
