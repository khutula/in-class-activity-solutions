# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('https://2u-data-curriculum-team.s3.amazonaws.com/dataviz-classroom/v1.1/21-Deep-Learning/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
# Remove diabetes outcome target from features data
y = diabetes_df["Outcome"]
X = diabetes_df.drop(["Outcome"], 1)

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
# Fit the StandardScaler
scaler = StandardScaler().fit(X_train)

# Scale the data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.6753
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6619 - accuracy: 0.6927
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6363 - accuracy: 0.7101
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6105 - accuracy: 0.7170
# Epoch 5/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5846 - accuracy: 0.7153
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5615 - accuracy: 0.7257
# Epoch 7/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5406 - accuracy: 0.7326
# Epoch 8/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5220 - accuracy: 0.7378
# Epoch 9/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5082 - accuracy: 0.7552
# Epoch 10/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4955 - accuracy: 0.7552
# Epoch 11/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4854 - accuracy: 0.7639
# Epoch 12/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4766 - accuracy: 0.7674
# Epoch 13/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4696 - accuracy: 0.7726
# Epoch 14/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4625 - accuracy: 0.7708
# Epoch 15/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4577 - accuracy: 0.7760
# Epoch 16/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4528 - accuracy: 0.7795
# Epoch 17/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4500 - accuracy: 0.7778
# Epoch 18/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4471 - accuracy: 0.7830
# Epoch 19/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4440 - accuracy: 0.7830
# Epoch 20/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4417 - accuracy: 0.7812
# Epoch 21/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4389 - accuracy: 0.7830
# Epoch 22/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4367 - accuracy: 0.7830
# Epoch 23/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4353 - accuracy: 0.7795
# Epoch 24/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4334 - accuracy: 0.7830
# Epoch 25/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4318 - accuracy: 0.7830
# Epoch 26/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4299 - accuracy: 0.7865
# Epoch 27/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4291 - accuracy: 0.7812
# Epoch 28/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4259 - accuracy: 0.7899
# Epoch 29/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4246 - accuracy: 0.7899
# Epoch 30/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4227 - accuracy: 0.7917
# Epoch 31/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4210 - accuracy: 0.7882
# Epoch 32/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4192 - accuracy: 0.7917
# Epoch 33/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4184 - accuracy: 0.7934
# Epoch 34/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4173 - accuracy: 0.7899
# Epoch 35/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4151 - accuracy: 0.7917
# Epoch 36/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4137 - accuracy: 0.7934
# Epoch 37/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4123 - accuracy: 0.7917
# Epoch 38/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4126 - accuracy: 0.7986
# Epoch 39/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4122 - accuracy: 0.7899
# Epoch 40/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4090 - accuracy: 0.7986
# Epoch 41/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4076 - accuracy: 0.7986
# Epoch 42/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4069 - accuracy: 0.7969
# Epoch 43/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4068 - accuracy: 0.7899
# Epoch 44/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4045 - accuracy: 0.8021
# Epoch 45/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4032 - accuracy: 0.7986
# Epoch 46/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4025 - accuracy: 0.7969
# Epoch 47/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4011 - accuracy: 0.8003
# Epoch 48/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4010 - accuracy: 0.7951
# Epoch 49/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3991 - accuracy: 0.7951
# Epoch 50/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3986 - accuracy: 0.7986
# Epoch 51/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3981 - accuracy: 0.8038
# Epoch 52/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3967 - accuracy: 0.8038
# Epoch 53/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8003
# Epoch 54/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3952 - accuracy: 0.8021
# Epoch 55/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3940 - accuracy: 0.8056
# Epoch 56/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3928 - accuracy: 0.8038
# Epoch 57/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3917 - accuracy: 0.8038
# Epoch 58/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3919 - accuracy: 0.8073
# Epoch 59/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3902 - accuracy: 0.8090
# Epoch 60/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3888 - accuracy: 0.8090
# Epoch 61/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3885 - accuracy: 0.8160
# Epoch 62/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3871 - accuracy: 0.8108
# Epoch 63/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3864 - accuracy: 0.8125
# Epoch 64/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3850 - accuracy: 0.8125
# Epoch 65/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3843 - accuracy: 0.8142
# Epoch 66/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3833 - accuracy: 0.8160
# Epoch 67/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3826 - accuracy: 0.8125
# Epoch 68/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3814 - accuracy: 0.8160
# Epoch 69/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3814 - accuracy: 0.8160
# Epoch 70/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3801 - accuracy: 0.8177
# Epoch 71/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3788 - accuracy: 0.8142
# Epoch 72/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3774 - accuracy: 0.8142
# Epoch 73/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3766 - accuracy: 0.8142
# Epoch 74/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3759 - accuracy: 0.8177
# Epoch 75/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3746 - accuracy: 0.8125
# Epoch 76/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3740 - accuracy: 0.8142
# Epoch 77/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3725 - accuracy: 0.8125
# Epoch 78/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3715 - accuracy: 0.8194
# Epoch 79/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3708 - accuracy: 0.8160
# Epoch 80/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3693 - accuracy: 0.8177
# Epoch 81/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3684 - accuracy: 0.8160
# Epoch 82/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3682 - accuracy: 0.8194
# Epoch 83/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3668 - accuracy: 0.8177
# Epoch 84/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3655 - accuracy: 0.8212
# Epoch 85/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3660 - accuracy: 0.8247
# Epoch 86/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3638 - accuracy: 0.8264
# Epoch 87/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3626 - accuracy: 0.8299
# Epoch 88/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3623 - accuracy: 0.8281
# Epoch 89/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3614 - accuracy: 0.8316
# Epoch 90/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3599 - accuracy: 0.8264
# Epoch 91/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3587 - accuracy: 0.8264
# Epoch 92/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3585 - accuracy: 0.8247
# Epoch 93/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3574 - accuracy: 0.8264
# Epoch 94/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3562 - accuracy: 0.8299
# Epoch 95/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3555 - accuracy: 0.8281
# Epoch 96/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3549 - accuracy: 0.8333
# Epoch 97/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3545 - accuracy: 0.8368
# Epoch 98/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3529 - accuracy: 0.8299
# Epoch 99/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3530 - accuracy: 0.8316
# Epoch 100/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3517 - accuracy: 0.8299
# 6/6 - 0s - loss: 0.6128 - accuracy: 0.7344
